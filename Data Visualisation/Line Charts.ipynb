# %% [markdown]
# In this session we'll be using the Spotify dataset to make some interesting Line Charts.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)# this is just for supressing warnings

# %%
oo=pd.read_csv('spotify.csv',index_col='Date',parse_dates=True)

# %% [markdown]
# In this dataset we are going to be focusing on the 5 most popular songs from 2017 and 2018:
#
#     1) "Shape of You", by Ed Sheeran
#     2) "Despacito", by Luis Fonzi
#     3) "Something Just Like This", by The Chainsmokers and Coldplay
#     4) "HUMBLE", by Kendrick Lamar
#     5) "Unforgettable", by French Montana

# %%
oo.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %%
oo.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %% [markdown]
# So we can see that nobody was streaming these songs earlier( obviously, because they didn't exist! ) but a song like "Despacito" had 3450315 streams on the 5th of January 2018.

# %% [markdown]
# Now that we understand our dataset, we can start plotting the data.

# %%
sns.lineplot(data=oo);

# %% [markdown]
# **sns.lineplot** tells the notebook that we want to create a line chart.
# Every command that you learn about in this course will start with sns, which indicates that the command comes from the seaborn package. For instance, we use sns.lineplot to make line charts. Soon, you'll learn that we use sns.barplot and sns.heatmap to make bar charts and heatmaps, respectively.

# %% [markdown]
# **data=oo** selects the data that will be used to create the chart.

# %% [markdown]
# As you can see, the plot illustrates the popularity of these songs over time.
# The most interesting insight that we can gather from this plot is how quickly the song "Despacito" became popular 4 months after its release.

# %% [markdown]
# The plot however looks a bit small and we should probably add some extra details to make it look better

# %% [markdown]
# We can do this by:-

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=oo)

# %% [markdown]
# We can also add a title:-

# %%
plt.figure(figsize=(20,10))
plt.title('Daily Global Streams of Popular Songs in 2017-2018 on Spotify')
sns.lineplot(data=oo)

# %% [markdown]
# Our plot is now starting to look a little better.

# %% [markdown]
# What if I just wanted to see a comparison between "HUMBLE." and "Shape of You"?

# %%
plt.figure(figsize=(10,5))
plt.title('HUMBLE. vs Shape of You')
sns.lineplot(data=oo['HUMBLE.'],label="HUMBLE.")
sns.lineplot(data=oo['Shape of You'],label="Shape of You")
